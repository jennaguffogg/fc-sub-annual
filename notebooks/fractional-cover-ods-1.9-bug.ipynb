# %% [markdown]
# While testing the unstable sandbox environment on 19/8/25, encountered an issue with using the fractional cover package with the new datacube 1.9
#
# FC repo for context: https://github.com/GeoscienceAustralia/fc
#
# If you run this script with datacube==1.9, the code will throw an error.
#
# If you un-comment the lines that uninstall datacube and re-install datacube 1.8, then the script will execute without error.

# %%
# %xmode verbose
# Out:
# Exception reporting mode: Verbose

# %%
# %pip install fractional_cover --find-links="https://packages.dea.ga.gov.au/fc" -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip uninstall datacube -y
# %pip install datacube==1.8.0 -q

# %%
import os
import yaml
import datacube
import numpy as np
import pandas as pd
import xarray as xr
import geopandas as gpd

from fc.fractional_cover import (
    fractional_cover,
)  # import the FC package after installing it above

from odc.geo.xr import assign_crs
from odc.geo.geom import Geometry
from odc.algo import keep_good_only
from odc.algo._percentile import xr_quantile_bands
from datacube.model import Measurement
from datacube.utils import unsqueeze_dataset, masking

import sys

sys.path.insert(1, "/home/jovyan/dev/Tools/")
from dea_tools.datahandling import load_ard
from dea_tools.dask import create_local_dask_cluster

# %%
# !pip list | grep datacube
# Out:
# datacube                          1.9.7
# datacube_ows                      1.9.4

# %% [markdown]
# There is a yaml file in this directory that contains the additional information needed to run the fractional cover function alter on.

# %%
# Read YAML file
with open("/home/jovyan/git/fc-sub-annual/notebooks/variables.yaml", "r") as f:
    config = yaml.safe_load(f)

# Extract variables
MEASUREMENTS = config["measurements"]
LANDSAT_SENSOR_REGRESSION_COEFFICIENTS = config[
    "landsat_sensor_regression_coefficients"
]
SENTINEL_SENSOR_REGRESSION_COEFFICIENTS = config[
    "sentinel_sensor_regression_coefficients"
]
LANDSAT_BAND_MAPPING = config["landsat_band_mapping"]
SENTINEL_BAND_MAPPING = config["sentinel_band_mapping"]

# Convert measurements to Measurement objects
MEASUREMENTS_OBJ = [Measurement(**m) for m in MEASUREMENTS]

# %%
dc = datacube.Datacube(app="fc_odc_unstable_img_bug")

# %%
lat = -35.5200
lon = 144.0000
buffer = 0.01

lat_range = (lat - buffer, lat + buffer)
lon_range = (lon - buffer, lon + buffer)

# %%
query = {
    "x": lon_range,
    "y": lat_range,
    "time": ("2024-01-01", "2024-01-31"),
    "resolution": (-30, 30),
    "group_by": "solar_day",
    "output_crs": "EPSG:3577",
}

# %%
ls_ds = load_ard(
    dc=dc,
    products=["ga_ls8c_ard_3", "ga_ls9c_ard_3"],
    measurements=[
        "nbart_green",
        "nbart_red",
        "nbart_nir",
        "nbart_swir_1",
        "nbart_swir_2",
    ],
    cloud_mask="fmask",
    mask_pixel_quality=True,
    fmask_categories=["valid", "snow", "water"],
    mask_filters=[("dilation", 5)],
    mask_contiguity=True,
    skip_broken_datasets=True,
    verbose=True,
    **query
)
# Out:
# Finding datasets
#     ga_ls8c_ard_3
#     ga_ls9c_ard_3
# Applying morphological filters to pixel quality mask: [('dilation', 5)]
# Applying fmask pixel quality/cloud mask
# Applying contiguity mask (oa_nbart_contiguity)
# Loading 7 time steps
# /home/jovyan/dev/Tools/dea_tools/datahandling.py:519: UserWarning: As of `dea_tools` v0.3.0, pixel quality masks are inverted before being passed to `mask_filters` (i.e. so that good quality/clear pixels are False and poor quality pixels/clouds are True). This means that 'dilation' will now expand cloudy pixels, rather than shrink them as in previous versions.
#   warnings.warn(
# /env/lib/python3.10/site-packages/rasterio/warp.py:387: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dest = _reproject(

# %%
# band renaming to make sure the bands are named correctly for the fractional cover function
for mapping in LANDSAT_BAND_MAPPING:
    if mapping["rename"]:
        ls_rename_dict = mapping["rename"]
        break

ls_renamed = ls_ds.rename(ls_rename_dict)

# %%
test_da = ls_renamed.isel(time=0)
test_da
# Out:
# <xarray.Dataset> Size: 111kB
# Dimensions:      (y: 81, x: 68)
# Coordinates:
#     time         datetime64[ns] 8B 2024-01-01T00:09:22.123303
#   * y            (y) float64 648B -3.93e+06 -3.93e+06 ... -3.932e+06 -3.932e+06
#   * x            (x) float64 544B 1.084e+06 1.084e+06 ... 1.086e+06 1.086e+06
#     spatial_ref  int32 4B 3577
# Data variables:
#     green        (y, x) float32 22kB nan nan nan nan ... 491.0 506.0 513.0 510.0
#     red          (y, x) float32 22kB nan nan nan nan ... 489.0 512.0 493.0 500.0
#     nir          (y, x) float32 22kB nan nan nan ... 2.331e+03 2.247e+03
#     swir1        (y, x) float32 22kB nan nan nan ... 1.338e+03 1.398e+03
#     swir2        (y, x) float32 22kB nan nan nan nan ... 757.0 783.0 749.0 790.0
# Attributes:
#     crs:           EPSG:3577
#     grid_mapping:  spatial_ref

# %%
ls_fc = fractional_cover(
    test_da, MEASUREMENTS_OBJ, LANDSAT_SENSOR_REGRESSION_COEFFICIENTS
)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 ls_fc = fractional_cover(
#         test_da = <xarray.Dataset> Size: 111kB
# Dimensions:      (y: 81, x: 68)
# Coordinates:
#     time         datetime64[ns] 8B 2024-01-01T00:09:22.123303
#   * y            (y) float64 648B -3.93e+06 -3.93e+06 ... -3.932e+06 -3.932e+06
#   * x            (x) float64 544B 1.084e+06 1.084e+06 ... 1.086e+06 1.086e+06
#     spatial_ref  int32 4B 3577
# Data variables:
#     green        (y, x) float32 22kB nan nan nan nan ... 491.0 506.0 513.0 510.0
#     red          (y, x) float32 22kB nan nan nan nan ... 489.0 512.0 493.0 500.0
#     nir          (y, x) float32 22kB nan nan nan ... 2.331e+03 2.247e+03
#     swir1        (y, x) float32 22kB nan nan nan ... 1.338e+03 1.398e+03
#     swir2        (y, x) float32 22kB nan nan nan nan ... 757.0 783.0 749.0 790.0
# Attributes:
#     crs:           EPSG:3577
#     grid_mapping:  spatial_ref
#         MEASUREMENTS_OBJ = [Measurement({'name': 'BS', 'src_var': 'BS', 'units': 'percent', 'dtype': 'int8', 'nodata': -1, 'zlib': True, 'fletcher32': True, 'attrs': {'long_name': 'Bare ground fraction percentage', 'comment': 'Fraction of bare ground including rock, bare and disturbed soil, within the Landsat pixel as percentages', 'alias': 'bare', 'coverage_content_type': 'modelResult'}, 'aliases': ['bare']}), Measurement({'name': 'PV', 'src_var': 'PV', 'units': 'percent', 'dtype': 'int8', 'nodata': -1, 'zlib': True, 'fletcher32': True, 'attrs': {'long_name': 'Green cover fraction percentage', 'comment': 'Fraction of green cover including green groundcover and green leaf material over all strata, within the Landsat pixel, as percentages', 'alias': 'green', 'coverage_content_type': 'modelResult'}, 'aliases': ['green_veg']}), Measurement({'name': 'NPV', 'src_var': 'NPV', 'units': 'percent', 'dtype': 'int8', 'nodata': -1, 'zlib': True, 'fletcher32': True, 'attrs': {'long_name': 'Non-green cover fraction percentage', 'comment': 'Fraction of non green cover including litter, dead leaf and branches over all strata, within the Landsat pixel, as percentages', 'alias': 'dead', 'coverage_content_type': 'modelResult'}, 'aliases': ['dead_veg']}), Measurement({'name': 'UE', 'src_var': 'UE', 'units': '1', 'dtype': 'int8', 'nodata': -1, 'zlib': True, 'fletcher32': True, 'attrs': {'long_name': 'Unmixing error', 'comment': 'Euclidean Norm of the Residual Vector', 'alias': 'err', 'coverage_content_type': 'qualityInformation'}, 'aliases': ['err']})]
#         LANDSAT_SENSOR_REGRESSION_COEFFICIENTS = {'blue': [0.00041, 0.9747], 'green': [0.00289, 0.99779], 'red': [0.00274, 1.00446], 'nir': [4e-05, 0.98906], 'swir1': [0.00256, 0.99467], 'swir2': [-0.00327, 1.02551]}
#       2     test_da, MEASUREMENTS_OBJ, LANDSAT_SENSOR_REGRESSION_COEFFICIENTS
#       3 )
#
# File /env/lib/python3.10/site-packages/fc/fractional_cover.py:129, in fractional_cover(nbar_tile=<xarray.Dataset> Size: 111kB
# Dimensions:      (y...         EPSG:3577
#     grid_mapping:  spatial_ref, measurements=[Measurement({'name': 'BS', 'src_var': 'BS', 'uni...tent_type': 'modelResult'}, 'aliases': ['bare']}), Measurement({'name': 'PV', 'src_var': 'PV', 'uni...type': 'modelResult'}, 'aliases': ['green_veg']}), Measurement({'name': 'NPV', 'src_var': 'NPV', 'u..._type': 'modelResult'}, 'aliases': ['dead_veg']}), Measurement({'name': 'UE', 'src_var': 'UE', 'uni...ype': 'qualityInformation'}, 'aliases': ['err']})], regression_coefficients={'blue': [0.00041, 0.9747], 'green': [0.00289, 0.99779], 'nir': [4e-05, 0.98906], 'red': [0.00274, 1.00446], 'swir1': [0.00256, 0.99467], 'swir2': [-0.00327, 1.02551]}, clip_after_regression=False, output_regression_coefficients=None)
#     126     no_error = unmasked_var != error_val
#     127     return where(is_valid_array.data & no_error, unmasked_var, band_nodata)
# --> 129 dataset = Datacube.create_storage({}, nbar_tile.geobox, measurements, data_func)
#         nbar_tile = <xarray.Dataset> Size: 111kB
# Dimensions:      (y: 81, x: 68)
# Coordinates:
#     time         datetime64[ns] 8B 2024-01-01T00:09:22.123303
#   * y            (y) float64 648B -3.93e+06 -3.93e+06 ... -3.932e+06 -3.932e+06
#   * x            (x) float64 544B 1.084e+06 1.084e+06 ... 1.086e+06 1.086e+06
#     spatial_ref  int32 4B 3577
# Data variables:
#     green        (y, x) float32 22kB nan nan nan nan ... 491.0 506.0 513.0 510.0
#     red          (y, x) float32 22kB nan nan nan nan ... 489.0 512.0 493.0 500.0
#     nir          (y, x) float32 22kB nan nan nan ... 2.331e+03 2.247e+03
#     swir1        (y, x) float32 22kB nan nan nan ... 1.338e+03 1.398e+03
#     swir2        (y, x) float32 22kB nan nan nan nan ... 757.0 783.0 749.0 790.0
# Attributes:
#     crs:           EPSG:3577
#     grid_mapping:  spatial_ref
#         measurements = [Measurement({'name': 'BS', 'src_var': 'BS', 'units': 'percent', 'dtype': 'int8', 'nodata': -1, 'zlib': True, 'fletcher32': True, 'attrs': {'long_name': 'Bare ground fraction percentage', 'comment': 'Fraction of bare ground including rock, bare and disturbed soil, within the Landsat pixel as percentages', 'alias': 'bare', 'coverage_content_type': 'modelResult'}, 'aliases': ['bare']}), Measurement({'name': 'PV', 'src_var': 'PV', 'units': 'percent', 'dtype': 'int8', 'nodata': -1, 'zlib': True, 'fletcher32': True, 'attrs': {'long_name': 'Green cover fraction percentage', 'comment': 'Fraction of green cover including green groundcover and green leaf material over all strata, within the Landsat pixel, as percentages', 'alias': 'green', 'coverage_content_type': 'modelResult'}, 'aliases': ['green_veg']}), Measurement({'name': 'NPV', 'src_var': 'NPV', 'units': 'percent', 'dtype': 'int8', 'nodata': -1, 'zlib': True, 'fletcher32': True, 'attrs': {'long_name': 'Non-green cover fraction percentage', 'comment': 'Fraction of non green cover including litter, dead leaf and branches over all strata, within the Landsat pixel, as percentages', 'alias': 'dead', 'coverage_content_type': 'modelResult'}, 'aliases': ['dead_veg']}), Measurement({'name': 'UE', 'src_var': 'UE', 'units': '1', 'dtype': 'int8', 'nodata': -1, 'zlib': True, 'fletcher32': True, 'attrs': {'long_name': 'Unmixing error', 'comment': 'Euclidean Norm of the Residual Vector', 'alias': 'err', 'coverage_content_type': 'qualityInformation'}, 'aliases': ['err']})]
#     131 return dataset
#
# File /env/lib/python3.10/site-packages/datacube/api/core.py:788, in Datacube.create_storage(coords={}, geobox=GeoBox((81, 68), Affine(30.0, 0.0, 1084350.0,
#   ...X[-43.7,112.85,-9.86,153.69]],ID["EPSG",3577]]')), measurements=[Measurement({'name': 'BS', 'src_var': 'BS', 'uni...tent_type': 'modelResult'}, 'aliases': ['bare']}), Measurement({'name': 'PV', 'src_var': 'PV', 'uni...type': 'modelResult'}, 'aliases': ['green_veg']}), Measurement({'name': 'NPV', 'src_var': 'NPV', 'u..._type': 'modelResult'}, 'aliases': ['dead_veg']}), Measurement({'name': 'UE', 'src_var': 'UE', 'uni...ype': 'qualityInformation'}, 'aliases': ['err']})], data_func=<function fractional_cover.<locals>.data_func>, extra_dims=None)
#     786 dims_default: tuple[Hashable, ...] = ()
#     787 if coords is not None:
# --> 788     coords_value = next(iter(coords.values()))
#         coords = {}
#     789     if isinstance(coords_value, xarray.DataArray):
#     790         dims_default = coords_value.dims + geobox.dimensions
#
# StopIteration:
